# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
EmpTitle_Code_df = pd.read_csv("../TraEdExp_AJ/EmpTitle_Code.csv")
EmpTitle_Code_df.rename(columns={'Unnamed: 0':'Index', 
                                 'Employment Matrix Title':'Title', 
                                 'Employment Matrix Code':'Code'}, 
                        inplace=True)
EmpTitle_Code_df.set_index("Index", inplace=True)
EmpTitle_Code_df.head()
# Out:
#                                               Title     Code
# Index
# 3                         Computer systems analysts  15-1211
# 4                     Information security analysts  15-1212
# 5      Computer and information research scientists  15-1221
# 7              Computer network support specialists  15-1231
# 8                 Computer user support specialists  15-1232

# %%
TrainingEduationExperience_df = pd.read_csv("../TraEdExp_AJ/TrainingEduationExperience.csv")
TrainingEduationExperience_df.rename(columns={'Unnamed: 0':'Index', 
                                              'Employment Matrix Title':'Title', 
                                              'Employment Matrix Code':'Code', 
                                              'Typical education needed for entry': 'Education',
                                              'Less than high school diploma': 'Less_HighSchool',
                                              'High school diploma or equivalent': 'HighSchool',
                                              'Some college, no degree': 'Some_College',
                                              "Associate's degree": 'Associate_Degree',
                                              "Bachelor's degree":'Bachelor_Degree',
                                              "Master's degree":'Master_Degree',
                                              "Doctoral or professional degree":'Doctoral_Professional_Degree',
                                              "Related Work Experience":'Experience',
                                              "Typical on-the-job training":'Training'}, 
                                     inplace=True)
TrainingEduationExperience_df.set_index("Index", inplace=True)
TrainingEduationExperience_df.head()
# Out:
#                                               Title     Code  \
# Index
# 3                         Computer systems analysts  15-1211
# 4                     Information security analysts  15-1212
# 5      Computer and information research scientists  15-1221
# 7              Computer network support specialists  15-1231
# 8                 Computer user support specialists  15-1232
#
#                      Education  Less_HighSchool  HighSchool  Some_College  \
# Index
# 3            Bachelor's degree              0.5         5.4          12.8
# 4            Bachelor's degree              0.8         4.2          17.2
# 5              Master's degree              0.0         0.9           5.9
# 7           Associate's degree              0.8         9.9          25.2
# 8      Some college, no degree              0.8         9.9          25.2
#
#        Associate_Degree  Bachelor_Degree  Master_Degree  \
# Index
# 3                   7.8             46.4           24.0
# ...

# %%
employment_occupation_df = pd.read_csv("../Job Growth/employment_occupation.csv")
employment_occupation_df.rename(columns={'Unnamed: 0':'Index',
                                         "Employment Matrix title": 'Title',
                                         "Employment Matrix code": 'Code',
                                         "2019 Employment": '2019_Employment',
                                         "2029 Employment": '2029_Employment',
                                         "Number of Employment changes, 2019-29": '2019-2029_Change',
                                         "Percent Employment change, 2019-29": '2019-2029_Percent_Change'}, 
                                inplace=True)
employment_occupation_df.set_index("Index", inplace=True)
employment_occupation_df.head()
# Out:
#                                                    Title     Code  \
# Index
# 5                  Computer and mathematical occupations  15-0000
# 9                                      Legal occupations  23-0000
# 10       Educational instruction and library occupations  25-0000
# 12     Healthcare practitioners and technical occupat...  29-0000
# 13                        Healthcare support occupations  31-0000
#
#       2019_Employment 2029_Employment 2019-2029_Change  \
# Index
# 5             4,845.1         5,432.4            587.4
# 9             1,335.6         1,403.2             67.6
# 10            9,744.7        10,185.6            441.0
# 12            9,133.7         9,967.3            833.6
# 13            7,013.4         8,598.1          1,584.8
#
#        2019-2029_Percent_Change
# Index
# 5                          12.1
# 9                           5.1
# 10                          4.5
# 12                          9.1
# 13                         22.6

# %%
fastest_decline_df = pd.read_csv("../Job Growth/fastest_decline.csv")
fastest_decline_df.rename(columns={'Unnamed: 0':'Index',
                                    "Employment Matrix title": 'Title',
                                    "Employment Matrix code": 'Code',
                                    "2019 Employment": '2019_Employment',
                                    "2029 Employment": '2029_Employment',
                                    "Number of Employment changes, 2019-29": '2019-2029_Change',
                                    "Percent Employment change, 2019-29": '2019-2029_Percent_Change'}, 
                          inplace=True)
fastest_decline_df.set_index("Index", inplace=True)
fastest_decline_df.head()
# Out:
#                                                    Title     Code  \
# Index
# 9                                          Travel agents  41-3041
# 21     Door-to-door sales workers, news and street ve...  41-9091
#
#        2019_Employment  2029_Employment  2019-2029_Change  \
# Index
# 9                 82.0             60.8             -21.3
# 21                72.9             58.3             -14.6
#
#        2019-2029_Percent_Change
# Index
# 9                         -25.9
# 21                        -20.0

# %%
fastest_growing_df = pd.read_csv("../Job Growth/fastest_growing.csv")
fastest_growing_df.rename(columns={'Unnamed: 0':'Index',
                                    "Employment Matrix title": 'Title',
                                    "Employment Matrix code": 'Code',
                                    "2019 Employment": '2019_Employment',
                                    "2029 Employment": '2029_Employment',
                                    "Number of Employment changes, 2019-29": '2019-2029_Change',
                                    "Percent Employment change, 2019-29": '2019-2029_Percent_Change'}, 
                          inplace=True)
fastest_growing_df.set_index("Index", inplace=True)
fastest_growing_df.head()
# Out:
#                                      Title     Code 2019_Employment  \
# Index
# 4                      Nurse practitioners  29-1171           211.3
# 6          Occupational therapy assistants  31-2011            47.1
# 7                            Statisticians  15-2041            42.7
# 8      Home health and personal care aides  31-1120         3,439.7
# 9            Physical therapist assistants  31-2021            98.7
#
#       2029_Employment 2019-2029_Change  2019-2029_Percent_Change
# Index
# 4               322.0            110.7                      52.4
# 6                63.5             16.3                      34.6
# 7                57.5             14.8                      34.6
# 8             4,599.2          1,159.5                      33.7
# 9               130.9             32.2                      32.6

# %%
projected_growth_df = pd.read_csv("../Job Growth/projected_growth.csv")
projected_growth_df.rename(columns={'Unnamed: 0':'Index',
                                    "Employment Matrix title": 'Title',
                                    "Employment Matrix code": 'Code',
                                    "Occupation Type": 'Occupation_Type',
                                    "2019 Employment": '2019_Employment',
                                    "2029 Employment": '2029_Employment',
                                    "Number of Employment changes, 2019-29": '2019-2029_Change',
                                    "Percent Employment change, 2019-29": '2019-2029_Percent_Change',
                                    "Percent self employed, 2019": 'Percent_self_employed_2019',
                                    "Occupational openings, 2019-29 annual average": 'Occupational_openings_2019-29_annual_average'}, 
                           inplace=True )
projected_growth_df.set_index("Index", inplace=True)
projected_growth_df.head()
# Out:
#                                               Title     Code Occupation_Type  \
# Index
# 83                        Computer systems analysts  15-1211       Line item
# 84                    Information security analysts  15-1212       Line item
# 85     Computer and information research scientists  15-1221       Line item
# 87             Computer network support specialists  15-1231       Line item
# 88                Computer user support specialists  15-1232       Line item
#
#       2019_Employment 2029_Employment 2019-2029_Change  \
# Index
# 83              632.4           679.0             46.6
# 84              131.0           171.9             40.9
# 85               32.7            37.7              5.0
# 87              195.1           207.7             12.6
# 88              687.2           741.9             54.8
#
#        2019-2029_Percent_Change Percent_self_employed_2019  \
# Index
# 83                          7.4                        3.0
# ...

# %%
county_codes_df = pd.read_csv("../geo_data_csvs/cleaned_data/county_codes.csv")
county_codes_df.set_index("Area_Code", inplace=True)
county_codes_df.head()
# Out:
#                          Area_Name
# Area_Code
# 1001       Autauga County, Alabama
# 1003       Baldwin County, Alabama
# 1005       Barbour County, Alabama
# 1007          Bibb County, Alabama
# 1009        Blount County, Alabama

# %%
industry_codes_df = pd.read_csv("../geo_data_csvs/cleaned_data/industry_codes.csv")
industry_codes_df.set_index("Industry_Code", inplace=True)
industry_codes_df.head()
# Out:
#                                    Industry_Name
# Industry_Code
# 10                      10 Total, all industries
# 101                          101 Goods-producing
# 1011           1011 Natural resources and mining
# 1012                           1012 Construction
# 1013                          1013 Manufacturing

# %%
state_coords_df = pd.read_csv("../geo_data_csvs/cleaned_data/state_coords.csv")
state_coords_df.rename(columns={'Unnamed: 0':'Index'}, 
                        inplace=True)
state_coords_df.set_index("Index", inplace=True)
state_coords_df.head()
# Out:
#                State  Latitude   Longitude
# Index
# 0          Wisconsin      44.5  -89.500000
# 1      West Virginia      39.0  -80.500000
# 2            Vermont      44.0  -72.699997
# 3              Texas      31.0 -100.000000
# 4       South Dakota      44.5 -100.000000

# %%
state_codes_df = pd.read_csv("../geo_data_csvs/cleaned_data/state_codes.csv")
state_codes_df.set_index("Area_Code", inplace=True)
state_codes_df.head()
# Out:
#                  State
# Area_Code
# 1             Alabama
# 2              Alaska
# 4             Arizona
# 5            Arkansas
# 6          California

# %%
state_emp_data_df = pd.read_csv("../geo_data_csvs/cleaned_data/state_emp_data.csv")
state_emp_data_df.rename(columns={'Unnamed: 0':'Index',
                                  "Occupation_Title": 'Title',
                                  "Occupation_Code": 'Code'}, 
                        inplace=True)
state_emp_data_df.set_index("Index", inplace=True)
state_emp_data_df.head()
# Out:
#        Area_Code     Code                                 Title  \
# Index
# 62             1  15-1211             Computer Systems Analysts
# 63             1  15-1212         Information Security Analysts
# 64             1  15-1231  Computer Network Support Specialists
# 65             1  15-1232     Computer User Support Specialists
# 66             1  15-1241           Computer Network Architects
#
#       Total_Employment Mean_Hourly_Income Hourly_10th_Percentile  \
# Index
# 62               4,310              42.12                  26.17
# 63               1,570              42.67                  23.93
# 64               1,210              29.66                  17.57
# 65               6,480              24.79                  15.16
# 66               1,310              52.76                  31.04
#
#       Hourly_25th_Percentile Median_Hourly_Income Hourly_75th_Percentile  \
# Index
# 62                     31.52                39.36                  50.82
# ...

# %%
national_emp_data_df = pd.read_csv("../geo_data_csvs/cleaned_data/national_emp_data.csv")
national_emp_data_df.rename(columns={'Unnamed: 0':'Index',
                                  "Occupation_Title": 'Title',
                                  "Occupation_Code": 'Code'}, 
                        inplace=True)
national_emp_data_df.set_index("Index", inplace=True)
national_emp_data_df.head()
# Out:
#        Area_Code     Code                                         Title  \
# Index
# 121           99  15-1211                     Computer Systems Analysts
# 122           99  15-1212                 Information Security Analysts
# 124           99  15-1221  Computer and Information Research Scientists
# 126           99  15-1231          Computer Network Support Specialists
# 127           99  15-1232             Computer User Support Specialists
#
#       Total_Employment Mean_Hourly_Income Hourly_10th_Percentile  \
# Index
# 121            589,060              46.23                  26.53
# 122            125,570              50.10                  27.79
# 124             30,780              61.28                  33.65
# 126            185,430              33.10                  18.75
# 127            647,330              27.19                  15.54
#
#       Hourly_25th_Percentile Median_Hourly_Income Hourly_75th_Percentile  \
# Index
# ...

# %%
SalaryFINAL_df = pd.read_csv("../SalaryFINAL.csv")
SalaryFINAL_df.rename(columns={'Unnamed: 0':'Index'}, 
                        inplace=True)
SalaryFINAL_df.set_index("Index", inplace=True)
SalaryFINAL_df.head()
# Out:
#           Code Median_Annual_Wage
# Index
# 79     15-0000          88,340.00
# 80     15-1200          88,240.00
# 81     15-1210          92,360.00
# 82     15-1211          90,920.00
# 83     15-1212          99,730.00

# %%
connection_string = f'postgres://xxwwfptolsuugo:e1670593b9094d48b2c2f856e276edeb9866894d1f817f4fcc0e2b1ea7afcfde@ec2-52-203-49-58.compute-1.amazonaws.com:5432/d83l06oke2nrl7'
engine = create_engine(connection_string)

# %%
engine.table_names()
# Out:
# ['state_coords',
#  'national_emp_data',
#  'state_emp_data',
#  'state_codes',
#  'industry_codes',
#  'salaryfinal',
#  'projected_growth',
#  'fastest_growing',
#  'fastest_decline',
#  'employment_occupation',
#  'trainingeduationexperience',
#  'emptitle',
#  'county_codes']

# %%
EmpTitle_Code_df.to_sql(name='emptitle', con=engine, if_exists='replace')
county_codes_df.to_sql(name='county_codes', con=engine, if_exists='replace')
state_coords_df.to_sql(name='state_coords', con=engine, if_exists='replace')
national_emp_data_df.to_sql(name='national_emp_data', con=engine, if_exists='replace')
state_emp_data_df.to_sql(name='state_emp_data', con=engine, if_exists='replace')
state_codes_df.to_sql(name='state_codes', con=engine, if_exists='replace')
industry_codes_df.to_sql(name='industry_codes', con=engine, if_exists='replace')
SalaryFINAL_df.to_sql(name='salaryfinal', con=engine, if_exists='replace')
projected_growth_df.to_sql(name='projected_growth', con=engine, if_exists='replace')
fastest_growing_df.to_sql(name='fastest_growing', con=engine, if_exists='replace')
fastest_decline_df.to_sql(name='fastest_decline', con=engine, if_exists='replace')
employment_occupation_df.to_sql(name='employment_occupation', con=engine, if_exists='replace')
TrainingEduationExperience_df.to_sql(name='trainingeduationexperience', con=engine, if_exists='replace')
